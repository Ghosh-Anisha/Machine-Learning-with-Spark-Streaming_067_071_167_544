# %%
with open("sgd2000.txt", "r", encoding="utf-8") as g:
    data = list(map(float, g.readlines()))

# %%
accuracy1=[]
precision1=[]
recall1=[]

# %%
count=0
for i in data:
    if(count%3==0):
        accuracy1.append(i)
        count+=1
    elif(count%3==1):
        precision1.append(i)
        count+=1
    else:
        recall1.append(i)
        count+=1

# %%
with open("bnb2000.txt", "r", encoding="utf-8") as g:
    data = list(map(float, g.readlines()))

# %%
accuracy2=[]
precision2=[]
recall2=[]

# %%
count=0
for i in data:
    if(count%3==0):
        accuracy2.append(i)
        count+=1
    elif(count%3==1):
        precision2.append(i)
        count+=1
    else:
        recall2.append(i)
        count+=1

# %%
with open("mnb2000.txt", "r", encoding="utf-8") as g:
    data = list(map(float, g.readlines()))

# %%
accuracy3=[]
precision3=[]
recall3=[]

# %%
count=0
for i in data:
    if(count%3==0):
        accuracy3.append(i)
        count+=1
    elif(count%3==1):
        precision3.append(i)
        count+=1
    else:
        recall3.append(i)
        count+=1

# %%
with open("kmc2000.txt", "r", encoding="utf-8") as g:
    data = list(map(float, g.readlines()))

# %%
accuracy4=[]
precision4=[]
recall4=[]

# %%
count=0
for i in data:
    if(count%3==0):
        accuracy4.append(i)
        count+=1
    elif(count%3==1):
        precision4.append(i)
        count+=1
    else:
        recall4.append(i)
        count+=1

# %%
import matplotlib.pyplot as plt
import numpy as np
x_list= [*range(0, 80000,2000)]
xpoints = np.array(x_list)
ypoints1 = np.array(accuracy1)
ypoints2= np.array(accuracy2)
ypoints3= np.array(accuracy3)
ypoints4= np.array(accuracy4)

plt.plot(xpoints, ypoints1, color='r')
plt.plot(xpoints, ypoints2, color='b')
plt.plot(xpoints, ypoints3, color='g')
plt.plot(xpoints, ypoints4, color='y')
plt.xlabel("Training over 80k samples in batches of 2000 for 4 models")
plt.ylabel("Accuracy")
plt.legend(['sgd', 'bnb', 'mnb','kmc'])
plt.show()
